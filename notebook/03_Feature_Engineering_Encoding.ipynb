# %%
# Import Required Libraries

# Data manipulation
import pandas as pd
import numpy as np

# For encoding and scaling
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Display all columns when checking data
pd.set_option("display.max_columns", None)

# %%
# Load the cleaned training data

df = pd.read_csv("../data/processed_data/train_clean.csv")

# Check shape and preview data
print(df.shape)
df.head()
# Out:
# /var/folders/4y/jgs7sbvs2n92vmw0q53pv0580000gn/T/ipykernel_9940/833283587.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/processed_data/train_clean.csv")
# (844392, 27)
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4  2015-07-31   5263        555     1      1            0
# 1      2          4  2015-07-31   6064        625     1      1            0
# 2      3          4  2015-07-31   8314        821     1      1            0
# 3      4          4  2015-07-31  13995       1498     1      1            0
# 4      5          4  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# 2                       12.0                    2006.0       1
# 3                        9.0                    2009.0       0
# 4                        4.0                    2015.0       0
#
#    Promo2SinceWeek  Promo2SinceYear    PromoInterval  Year  Month  Week  Day  \
# 0              0.0              0.0              NaN  2015      7     4   31
# 1             13.0           2010.0  Jan,Apr,Jul,Oct  2015      7     4   31
# 2             14.0           2011.0  Jan,Apr,Jul,Oct  2015      7     4   31
# 3              0.0              0.0              NaN  2015      7     4   31
# 4              0.0              0.0              NaN  2015      7     4   31
#
#    CompetitionDuration  Promo2Duration       CustomerBin CustomerGroup  \
# 0                  7.0             0.0    (536.0, 609.0]      501–1000
# 1                  8.0             5.0    (609.0, 688.0]      501–1000
# 2                  9.0             4.0    (780.0, 903.0]      501–1000
# 3                  6.0             0.0  (1116.0, 7388.0]         1000+
# 4                  0.0             0.0    (536.0, 609.0]      501–1000
#
#   CompetitionGroup
# 0      1001–2000 m
# 1       501–1000 m
# 2          5000+ m
# 3       501–1000 m
# 4          5000+ m

# %%
# Convert Date column to datetime format
df["Date"] = pd.to_datetime(df["Date"])

# %%
# Extract year from date
df["Year"] = df["Date"].dt.year

# Extract month (captures seasonality)
df["Month"] = df["Date"].dt.month

# Extract day of month
df["Day"] = df["Date"].dt.day

# Extract day of week (0 = Monday, 6 = Sunday)
df["WeekDay"] = df["Date"].dt.weekday

# Create a weekend indicator (Saturday & Sunday)
df["IsWeekend"] = df["WeekDay"].isin([5, 6]).astype(int)

# %%
# Drop Date column (already extracted useful information)
df.drop(columns=["Date"], inplace=True)

# %%
# List of categorical columns
categorical_cols = [
    "StoreType",
    "Assortment",
    "StateHoliday",
    "PromoInterval"
]

categorical_cols
# Out:
# ['StoreType', 'Assortment', 'StateHoliday', 'PromoInterval']

# %%
# Ensure all categorical columns are treated as strings
for col in categorical_cols:
    df[col] = df[col].astype(str)

# %%
# Initialize label encoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
# Seprate feature

# Target variable
y = df["Sales"].values.ravel()

# Feature set
X = df.drop(columns=["Sales"])

# %%
# Final feature list

X.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Customers', 'Open', 'Promo', 'StateHoliday',
#        'SchoolHoliday', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval', 'Year', 'Month',
#        'Week', 'Day', 'CompetitionDuration', 'Promo2Duration', 'CustomerBin',
#        'CustomerGroup', 'CompetitionGroup', 'WeekDay', 'IsWeekend'],
#       dtype='object')

# %%
# Check data types and preview
X.dtypes
# Out:
# Store                          int64
# DayOfWeek                      int64
# Customers                      int64
# Open                           int64
# Promo                          int64
# StateHoliday                   int64
# SchoolHoliday                  int64
# StoreType                      int64
# Assortment                     int64
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                  int64
# Year                           int32
# Month                          int32
# Week                           int64
# Day                            int32
# CompetitionDuration          float64
# Promo2Duration               float64
# CustomerBin                   object
# CustomerGroup                 object
# CompetitionGroup              object
# WeekDay                        int32
# IsWeekend                      int64
# dtype: object

# %%
# checking missing value

X.isnull().sum()
# Out:
# Store                        0
# DayOfWeek                    0
# Customers                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# Year                         0
# Month                        0
# Week                         0
# Day                          0
# CompetitionDuration          0
# Promo2Duration               0
# CustomerBin                  0
# CustomerGroup                0
# CompetitionGroup             0
# WeekDay                      0
# IsWeekend                    0
# dtype: int64

# %%
# Checking Duplicate value

X.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Define target variable

# Target shape
y.shape
# Out:
# (844392,)

# %%
# Target distribution summary

pd.Series(y).describe()
# Out:
# count    844392.000000
# mean       6955.514291
# std        3104.214680
# min           0.000000
# 25%        4859.000000
# 50%        6369.000000
# 75%        8360.000000
# max       41551.000000
# dtype: float64

# %%
# Drop EDA-only helper columns (not used for modeling)
eda_cols_to_drop = [
    "CustomerBin",
    "CustomerGroup",
    "CompetitionGroup"
]

df.drop(columns=eda_cols_to_drop, inplace=True)

# %%
# Define target
y = df["Sales"].values.ravel()

# Define features
X = df.drop(columns=["Sales"])

# %%
X.dtypes
# Out:
# Store                          int64
# DayOfWeek                      int64
# Customers                      int64
# Open                           int64
# Promo                          int64
# StateHoliday                   int64
# SchoolHoliday                  int64
# StoreType                      int64
# Assortment                     int64
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                  int64
# Year                           int32
# Month                          int32
# Week                           int64
# Day                            int32
# CompetitionDuration          float64
# Promo2Duration               float64
# WeekDay                        int32
# IsWeekend                      int64
# dtype: object

# %%
# Initialize scaler
scaler = StandardScaler()

# Scale features
X_scaled = scaler.fit_transform(X)

# Convert back to DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
# Final Validation after scaling

X_scaled.head()
# Out:
#       Store  DayOfWeek  Customers  Open     Promo  StateHoliday  \
# 0 -1.732571   0.858414  -0.517732   0.0  1.113726     -0.029796
# 1 -1.729462   0.858414  -0.343268   0.0  1.113726     -0.029796
# 2 -1.726354   0.858414   0.145233   0.0  1.113726     -0.029796
# 3 -1.723246   0.858414   1.832556   0.0  1.113726     -0.029796
# 4 -1.720138   0.858414  -0.507763   0.0  1.113726     -0.029796
#
#    SchoolHoliday  StoreType  Assortment  CompetitionDistance  \
# 0       2.041038   0.582814   -0.942988            -0.535816
# 1       2.041038  -0.884146   -0.942988            -0.625549
# 2       2.041038  -0.884146   -0.942988             1.112703
# 3       2.041038   0.582814    1.070916            -0.619139
# 4       2.041038  -0.884146   -0.942988             3.135536
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear    Promo2  \
# 0                   0.950941                  0.682279 -0.997372
# 1                   1.417831                  0.681210  1.002635
# 2                   1.651277                  0.680142  1.002635
# 3                   0.950941                  0.683348 -0.997372
# 4                  -0.216285                  0.689761 -0.997372
#
#    Promo2SinceWeek  Promo2SinceYear  PromoInterval      Year     Month  \
# 0        -0.757527        -0.997371       0.909585  1.502796  0.347258
# 1         0.091710         1.000890      -0.877596  1.502796  0.347258
# 2         0.157036         1.001885      -0.877596  1.502796  0.347258
# 3        -0.757527        -0.997371       0.909585  1.502796  0.347258
# 4        -0.757527        -0.997371       0.909585  1.502796  0.347258
#
#        Week       Day  CompetitionDuration  Promo2Duration   WeekDay  \
# 0  0.858414  1.746347             0.633683       -0.622407  0.858414
# 1  0.858414  1.746347             0.814779        2.387273  0.858414
# 2  0.858414  1.746347             0.995875        1.785337  0.858414
# 3  0.858414  1.746347             0.452588       -0.622407  0.858414
# 4  0.858414  1.746347            -0.633987       -0.622407  0.858414
#
#    IsWeekend
# 0  -0.460344
# 1  -0.460344
# 2  -0.460344
# 3  -0.460344
# 4  -0.460344

# %%
X_scaled.shape
# Out:
# (844392, 24)

# %%
# Save final feature-engineered dataset
# Save feature matrix
X_scaled.to_csv(
    "../data/processed_data/train_features.csv",
    index=False
)

# Save target variable
pd.Series(y).to_csv(
    "../data/processed_data/train_target.csv",
    index=False
)

print("Notebook 3 completed successfully.")
print("Feature matrix shape:", X_scaled.shape)
print("Target vector shape:", y.shape)
# Out:
# Notebook 3 completed successfully.
# Feature matrix shape: (844392, 24)
# Target vector shape: (844392,)
